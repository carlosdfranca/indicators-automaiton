# %% [markdown]
# ### Passo 1 - Importar Arquivos e Bibliotecas

# %%
#Importar Bibliotecas
import pandas as pd
from pathlib import Path

# %%
#Importas Arquivos

emails = pd.read_excel(r'Bases de dados\Emails.xlsx')
lojas = pd.read_csv(r'Bases de dados\Lojas.csv', encoding='latin1', sep=';')
vendas = pd.read_excel(r'Bases de dados\Vendas.xlsx')
display(emails)
display(lojas)
display(vendas)
# Out:
#                                 Loja          Gerente  \
# 0                 Iguatemi Esplanada          claudio
# 1               Shopping Midway Mall           hakeem
# 2                     Norte Shopping             zuri
# 3        Shopping Iguatemi Fortaleza          mariana
# 4           Shopping União de Osasco          juliana
# 5         Shopping Center Interlagos             caio
# 6                     Rio Mar Recife          vanessa
# 7                  Salvador Shopping           samara
# 8         Rio Mar Shopping Fortaleza          gabriel
# 9   Shopping Center Leste Aricanduva      chatingride
# 10                 Ribeirão Shopping        guilherme
# 11                  Shopping Morumbi            pedro
# 12         Parque Dom Pedro Shopping         henrique
# 13               Bourbon Shopping SP          douglas
# 14       Palladium Shopping Curitiba        edionélio
# 15         Passei das Águas Shopping   jubdiscleidson
# 16        Center Shopping Uberlândia  motociclevirson
# 17                   Shopping Recife            julia
# 18               Shopping Vila Velha            julio
# 19                Shopping SP Market          gustavo
# 20                 Shopping Eldorado           amanda
# 21               Shopping Ibirapuera           rydwan
# 22      Novo Shopping Ribeirão Preto          rwannda
# 23                 Iguatemi Campinas           rwency
# 24                    Shopping Barra           rhowan
# 25                         Diretoria           rhayla
#
#                                    E-mail
# 0           rwencybrian+claudio@gmail.com
# 1            rwencybrian+hakeem@gmail.com
# 2              rwencybrian+zuri@gmail.com
# 3           rwencybrian+mariana@gmail.com
# 4           rwencybrian+juliana@gmail.com
# 5              rwencybrian+caio@gmail.com
# 6           rwencybrian+vanessa@gmail.com
# 7            rwencybrian+samara@gmail.com
# 8           rwencybrian+gabriel@gmail.com
# 9       rwencybrian+chatingride@gmail.com
# 10        rwencybrian+guilherme@gmail.com
# 11            rwencybrian+pedro@gmail.com
# 12         rwencybrian+henrique@gmail.com
# 13          rwencybrian+douglas@gmail.com
# 14        rwencybrian+edionélio@gmail.com
# 15   rwencybrian+jubdiscleidson@gmail.com
# 16  rwencybrian+motociclevirson@gmail.com
# 17            rwencybrian+julia@gmail.com
# 18            rwencybrian+julio@gmail.com
# 19          rwencybrian+gustavo@gmail.com
# 20           rwencybrian+amanda@gmail.com
# 21           rwencybrian+rydwan@gmail.com
# 22          rwencybrian+rwannda@gmail.com
# 23           rwencybrian+rwency@gmail.com
# 24           rwencybrian+rhowan@gmail.com
# 25           rwencybrian+rhayla@gmail.com
#     ID Loja                              Loja
# 0         1                Iguatemi Esplanada
# 1         2              Shopping Midway Mall
# 2         3                    Norte Shopping
# 3         4       Shopping Iguatemi Fortaleza
# 4         5          Shopping União de Osasco
# 5         6        Shopping Center Interlagos
# 6         7                    Rio Mar Recife
# 7         8                 Salvador Shopping
# 8         9        Rio Mar Shopping Fortaleza
# 9        10  Shopping Center Leste Aricanduva
# 10       11                 Ribeirão Shopping
# 11       12                  Shopping Morumbi
# 12       13         Parque Dom Pedro Shopping
# 13       14               Bourbon Shopping SP
# 14       15       Palladium Shopping Curitiba
# 15       16         Passei das Águas Shopping
# 16       17        Center Shopping Uberlândia
# 17       18                   Shopping Recife
# 18       19               Shopping Vila Velha
# 19       20                Shopping SP Market
# 20       21                 Shopping Eldorado
# 21       22               Shopping Ibirapuera
# 22       23      Novo Shopping Ribeirão Preto
# 23       24                 Iguatemi Campinas
# 24       25                    Shopping Barra
#         Código Venda       Data  ID Loja           Produto  Quantidade  \
# 0                  1 2019-01-01        1    Sapato Estampa           1
# 1                  1 2019-01-01        1          Camiseta           2
# 2                  1 2019-01-01        1     Sapato Xadrez           1
# 3                  2 2019-01-02        3           Relógio           3
# 4                  2 2019-01-02        3      Chinelo Liso           1
# ...              ...        ...      ...               ...         ...
# 100994         69996 2019-12-26       17    Short Listrado           2
# 100995         69996 2019-12-26       17           Mochila           4
# 100996         69996 2019-12-26       17  Pulseira Estampa           1
# 100997         69997 2019-12-26       11   Camisa Listrado           1
# 100998         69997 2019-12-26       11       Short Linho           2
#
#         Valor Unitário  Valor Final
# 0                  358          358
# 1                  180          360
# 2                  368          368
# 3                  200          600
# 4                   71           71
# ...                ...          ...
# 100994             102          204
# 100995             270         1080
# 100996              87           87
# 100997             108          108
# 100998             133          266
#
# [100999 rows x 7 columns]

# %% [markdown]
# ### Passo 2 - Definir Criar uma Tabela para cada Loja e Definir o dia do Indicador

# %%
# Incluir Lojas em vendas
vendas = vendas.merge(lojas, on='ID Loja')

# %%
#Criando tabela para cada Loja
dionario_loja = {}
for loja in lojas['Loja']:
    dicionario_loja[loja] = vendas.loc[vendas['Loja'] == loja, :]
# Out:
#       Código Venda       Data  ID Loja                 Produto  Quantidade  \
# 0                1 2019-01-01        1          Sapato Estampa           1
# 1                1 2019-01-01        1                Camiseta           2
# 2                1 2019-01-01        1           Sapato Xadrez           1
# 3               21 2019-01-02        1  Camisa Gola V Listrado           2
# 4               34 2019-01-02        1         Sapato Listrado           1
# ...            ...        ...      ...                     ...         ...
# 3975         69899 2019-12-25        1           Sapato Xadrez           4
# 3976         69903 2019-12-25        1              Terno Liso           5
# 3977         69928 2019-12-25        1                    Meia           1
# 3978         69944 2019-12-25        1            Gorro Xadrez           5
# 3979         69944 2019-12-25        1           Sapato Xadrez           2
#
#       Valor Unitário  Valor Final                Loja
# 0                358          358  Iguatemi Esplanada
# 1                180          360  Iguatemi Esplanada
# 2                368          368  Iguatemi Esplanada
# 3                116          232  Iguatemi Esplanada
# 4                363          363  Iguatemi Esplanada
# ...              ...          ...                 ...
# 3975             368         1472  Iguatemi Esplanada
# 3976             720         3600  Iguatemi Esplanada
# 3977              30           30  Iguatemi Esplanada
# 3978              85          425  Iguatemi Esplanada
# 3979             368          736  Iguatemi Esplanada
#
# [3980 rows x 8 columns]
#        Código Venda       Data  ID Loja                 Produto  Quantidade  \
# 72551            46 2019-01-02        7                  Camisa           1
# 72552            46 2019-01-02        7              Calça Liso           2
# 72553            46 2019-01-02        7                   Cinto           1
# 72554            87 2019-01-02        7          Camisa Estampa           1
# 72555           109 2019-01-02        7  Camisa Gola V Listrado           3
# ...             ...        ...      ...                     ...         ...
# 76645         69905 2019-12-25        7        Mochila Listrado           2
# 76646         69905 2019-12-25        7           Camisa Xadrez           3
# 76647         69905 2019-12-25        7              Tênis Liso           3
# 76648         69954 2019-12-25        7                 Chinelo           3
# 76649         69954 2019-12-25        7         Casaco Listrado           3
#
#        Valor Unitário  Valor Final            Loja
# 72551             100          100  Rio Mar Recife
# 72552             190          380  Rio Mar Recife
# 72553             200          200  Rio Mar Recife
# 72554             113          113  Rio Mar Recife
# 72555             116          348  Rio Mar Recife
# ...               ...          ...             ...
# 76645             275          550  Rio Mar Recife
# 76646             105          315  Rio Mar Recife
# 76647             266          798  Rio Mar Recife
# 76648              60          180  Rio Mar Recife
# 76649             269          807  Rio Mar Recife
#
# [4099 rows x 8 columns]
#        Código Venda       Data  ID Loja             Produto  Quantidade  \
# 12277             5 2019-01-02       25               Calça           1
# 12278            52 2019-01-02       25      Gorro Listrado           4
# 12279           100 2019-01-02       25  Camisa Gola V Liso           3
# 12280           100 2019-01-02       25        Cinto Xadrez           4
# 12281           132 2019-01-02       25         Terno Linho           2
# ...             ...        ...      ...                 ...         ...
# 16234         69908 2019-12-25       25           Meia Liso           2
# 16235         69908 2019-12-25       25              Camisa           1
# 16236         69913 2019-12-25       25               Gorro           1
# 16237         69913 2019-12-25       25         Cinto Linho           1
# 16238         69950 2019-12-25       25         Cinto Linho           1
#
#        Valor Unitário  Valor Final            Loja
# 12277             170          170  Shopping Barra
# 12278              97          388  Shopping Barra
# 12279             118          354  Shopping Barra
# 12280             215          860  Shopping Barra
# 12281             750         1500  Shopping Barra
# ...               ...          ...             ...
# 16234              38           76  Shopping Barra
# 16235             100          100  Shopping Barra
# 16236              80           80  Shopping Barra
# 16237             248          248  Shopping Barra
# 16238             248          248  Shopping Barra
#
# [3962 rows x 8 columns]

# %%
dia_indicador = vendas['Data'].max()
print(dia_indicador)
# Out:
# 2019-12-26 00:00:00

# %% [markdown]
# ### Passo 3 - Salvar a planilha na pasta de backup

# %%
#Identificar se a pasta ja existe
caminho_backup = Path(r'Backup Arquivos Lojas')

pastas_backup = caminho_backup.iterdir()

lista_nomes_backup = [pasta.name for pasta in pastas_backup]

for loja in dicionario_loja:
    if loja not in lista_nomes_backup:
        nova_pasta = caminho_backup / loja
        nova_pasta.mkdir()
    
    #salvar dentro da pasta
    nome_arquivo = f'{dia_indicador.month}_{dia_indicador.day}_{loja}.xlsx'
    local_arquivo = caminho_backup / loja / nome_arquivo
    dicionario_loja[loja].to_excel(local_arquivo, index=False)

# %% [markdown]
# ### Passo 4 - Calcular o indicador para 1 loja

# %%
loja = 'Norte Shopping'
vendas_loja = dicionario_loja[loja]
vendas_loja_dia = vendas_loja.loc[vendas_loja['Data']==dia_indicador, :]

#faturamento
faturamento_ano = vendas_loja['Valor Final'].sum()
faturamento_dia = vendas_loja_dia['Valor Final'].sum()
print(faturamento_ano)
print(faturamento_dia)
# Out:
# 1711968
# 1259

# %% [markdown]
# ### Passo 5 - Enviar por e-mail para o gerente

# %% [markdown]
# ### Passo 6 - Automatizar todas as lojas

# %% [markdown]
# ### Passo 7 - Criar ranking para diretoria

# %% [markdown]
# ### Passo 8 - Enviar e-mail para diretoria
